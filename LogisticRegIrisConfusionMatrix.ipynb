# %%
import pandas as pd

# %%
data = pd.read_csv('iris.csv')
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#To see the species that are available
data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#dealing with categorical data
data['Species'] = data['Species'].astype('category')
data['Species'] = data['Species'].cat.codes

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(columns = ['Species'])
y = data['Species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 23)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(max_iter = 1000)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
C = lr.intercept_
C
# Out:
# array([ 58.66878132,  22.10624595, -80.77502727])

# %%
m = lr.coef_
m
# Out:
# array([[-0.75669179, -0.29861305,  0.10690908, -0.64317835, -0.24924894],
#        [-0.112698  ,  0.14840826, -0.1825991 ,  0.04975791, -0.09664407],
#        [ 0.86938979,  0.1502048 ,  0.07569002,  0.59342044,  0.34589301]])

# %%
y_pred_train = lr.predict(X_train)

# %%
y_pred_train
# Out:
# array([0, 1, 0, 2, 0, 0, 1, 1, 1, 2, 2, 0, 1, 0, 1, 2, 2, 2, 0, 1, 2, 2,
#        0, 2, 1, 1, 2, 1, 0, 2, 1, 0, 1, 0, 2, 1, 1, 2, 2, 1, 0, 0, 2, 0,
#        0, 2, 2, 1, 0, 1, 2, 1, 2, 2, 1, 0, 1, 2, 2, 1, 0, 1, 1, 1, 2, 1,
#        1, 2, 2, 2, 0, 2, 1, 0, 2, 2, 0, 1, 1, 2, 0, 0, 1, 0, 1, 1, 0, 2,
#        1, 1, 0, 2, 1, 2, 2, 1, 0, 0, 2, 2, 1, 0, 2, 1, 2, 1, 0, 0, 0, 2,
#        0, 0, 2, 0, 1, 0, 1, 0, 0, 1], dtype=int8)

# %%
X_train
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 9     10            4.9           3.1            1.5           0.1
# 59    60            5.2           2.7            3.9           1.4
# 16    17            5.4           3.9            1.3           0.4
# 122  123            7.7           2.8            6.7           2.0
# 7      8            5.0           3.4            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 39    40            5.1           3.4            1.5           0.2
# 91    92            6.1           3.0            4.6           1.4
# 31    32            5.4           3.4            1.5           0.4
# 40    41            5.0           3.5            1.3           0.3
# 83    84            6.0           2.7            5.1           1.6
#
# [120 rows x 5 columns]

# %%
lr.score(X_train, y_pred_train)
# Out:
# 1.0

# %%
y_pred_test = lr.predict(X_test)

# %%
X_test
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 139  140            6.9           3.1            5.4           2.1
# 125  126            7.2           3.2            6.0           1.8
# 67    68            5.8           2.7            4.1           1.0
# 3      4            4.6           3.1            1.5           0.2
# 113  114            5.7           2.5            5.0           2.0
# 52    53            6.9           3.1            4.9           1.5
# 18    19            5.7           3.8            1.7           0.3
# 137  138            6.4           3.1            5.5           1.8
# 20    21            5.4           3.4            1.7           0.2
# 64    65            5.6           2.9            3.6           1.3
# 73    74            6.1           2.8            4.7           1.2
# 30    31            4.8           3.1            1.6           0.2
# 102  103            7.1           3.0            5.9           2.1
# ...

# %%
y_pred_test
# Out:
# array([2, 2, 1, 0, 2, 1, 0, 2, 0, 1, 1, 0, 2, 0, 0, 2, 1, 1, 2, 0, 2, 0,
#        0, 0, 2, 0, 0, 2, 1, 1], dtype=int8)

# %%
lr.score(X_test, y_pred_test)
# Out:
# 1.0

# %%
predicted_output = lr.predict(X_test)
predicted_output
# Out:
# array([2, 2, 1, 0, 2, 1, 0, 2, 0, 1, 1, 0, 2, 0, 0, 2, 1, 1, 2, 0, 2, 0,
#        0, 0, 2, 0, 0, 2, 1, 1], dtype=int8)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predicted_output)
cm
# Out:
# array([[12,  0,  0],
#        [ 0,  8,  0],
#        [ 0,  0, 10]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (5, 4))
sns.heatmap(cm, annot = True)
plt.xlabel('Predicted Value')
plt.ylabel('Actual Value')
# Out:
# Text(33.22222222222222, 0.5, 'Actual Value')

# %%
#what the heatmap means
#the model has predicted zero where the actual value is zero and this has happened 15 times.
#the model has predicted one where the actual value is 1, and this has happened 8 times
#the model has predicted two where the actual value is 2 and this has happened 10 times

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4)

# %%
lr1 = LogisticRegression(max_iter = 400).fit(X_train, y_train)

# %%
y_pred_test = lr1.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred_test)
cm
# Out:
# array([[21,  0,  0],
#        [ 0, 20,  0],
#        [ 0,  0, 19]])
